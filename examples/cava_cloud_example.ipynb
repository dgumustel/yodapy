# %% [markdown]
# # Yodapy Cloud Data Example

# %% [markdown]
# ## Inilization
#
# To access the OOI API, credentials need to be set. In order to set this up, switch to the python environment that contains yodapy and then fire up python.
#
# ```bash
# $ python
# ```
#
# Within the python console, set your credentials.
#
# ```python
# from yodapy.utils.creds import set_credentials_file
# set_credentials_file(data_source='ooi', username='Your OOI username', token='Your OOI token')
# ```
#
# The initialization step places a special .yodapy/.credentials file in your home directory. Your ~/.yodapy/.credentials file should look something like this
#
# ```json
# {"ooi": {"username": "Your OOI username", "api_key": "Your OOI token"}}
# ```

# %% [markdown]
# ## Getting started with yodapy

# %% [markdown]
# First we need to import all the necessary packages to retrieve and visualize some data from OOI. `yodapy` provides easy access to OOI by having an easy to use interface to search through available data in OOI system and retrieve the data in the form of xarray dataset.

# %%
from yodapy.datasources import OOI

# %% [markdown]
# The `cloud_source` argument is a flag for yodapy to retrieve the data from the cloud copy rather than OOI UFrame system.

# %%
ooi = OOI(cloud_source=True)

# %% [markdown]
# CAVA team have not included everything within the OOI system. To see which sites we currently have, we provided `cava_sites` attribute with `in_progress_status`. If `in_progress_status` is `True, this indicate that we are still in process of integrating that site.

# %%
ooi.cava_sites
# Out:
#    reference_designator                                          site_name  \
# 0              RS01SBPS                 Oregon Slope Base Shallow Profiler
# 1              CE04OSPS                   Oregon Offshore Shallow Profiler
# 2              RS03AXPS                        Axial Base Shallow Profiler
# 3              CE02SHBP     Oregon Shelf Cabled Benthic Experiment Package
# 4              CE04OSBP  Oregon Offshore Cabled Benthic Experiment Package
# 5              RS01SLBS                         Oregon Slope Base Seafloor
# 6              RS03ASHS                                   ASHES Vent Field
# 7              RS03AXBS                                Axial Base Seafloor
# 8              RS01SBPD                    Oregon Slope Base Deep Profiler
# 9              RS01SUM1                 Southern Hydrate Summit 2 Seafloor
# 10             RS01SUM2                 Southern Hydrate Summit 2 Seafloor
# 11             RS03AXPD                           Axial Base Deep Profiler
# 12             RS03CCAL                                    Central Caldera
# 13             RS03ECAL                                    Eastern Caldera
# 14             RS03INT1                International District Vent Field 1
# 15             RS03INT2                International District Vent Field 2
# 16             CE04OSPD               Oregon Offshore Cabled Deep Profiler
#
#                                              site_url               site_area  \
# 0                  /research-sites/oregon-slope-base/       Oregon Slope Base
# 1                    /research-sites/oregon-offshore/         Oregon Offshore
# 2                         /research-sites/axial-base/              Axial Base
# 3                       /research-sites/oregon-shelf/            Oregon Shelf
# 4                    /research-sites/oregon-offshore/         Oregon Offshore
# 5                  /research-sites/oregon-slope-base/       Oregon Slope Base
# 6                /research-sites/axial-caldera/ashes/           Axial Caldera
# 7                         /research-sites/axial-base/              Axial Base
# 8                  /research-sites/oregon-slope-base/       Oregon Slope Base
# 9             /research-sites/southern-hydrate-ridge/  Southern Hydrate Ridge
# 10            /research-sites/southern-hydrate-ridge/  Southern Hydrate Ridge
# 11                        /research-sites/axial-base/              Axial Base
# 12             /research-sites/axial-caldera/central/           Axial Caldera
# 13             /research-sites/axial-caldera/eastern/           Axial Caldera
# 14  /research-sites/axial-caldera/international-di...           Axial Caldera
# 15  /research-sites/axial-caldera/international-di...           Axial Caldera
# 16                   /research-sites/oregon-offshore/         Oregon Offshore
#
#     wp_mapping   map_icon_mapping  in_progress_status
# 0          518   shallow-profiler               False
# 1          518   shallow-profiler               False
# 2          518   shallow-profiler               False
# 3          512     low-power-jbox               False
# 4          512     low-power-jbox               False
# 5          512     low-power-jbox               False
# 6          512  medium-power-jbox               False
# 7          512     low-power-jbox               False
# 8          516      deep-profiler                True
# 9          429     low-power-jbox                True
# 10         429     low-power-jbox                True
# 11         516      deep-profiler                True
# 12         444  medium-power-jbox                True
# 13         446  medium-power-jbox                True
# 14         442  medium-power-jbox                True
# 15         442  medium-power-jbox                True
# 16         516      deep-profiler                True

# %% [markdown]
# The listing of instruments that we have can be found under `cava_instruments`

# %%
ooi.cava_instruments
# Out:
#    reference_designator                          instrument_name  \
# 0          2A-CTDPFA102                                    CTD-O
# 1          2A-CTDPFA107                                    CTD-O
# 2          2A-CTDPFA302                                    CTD-O
# 3          2B-PHSENA108                                       pH
# 4          2D-PHSENA101                                       pH
# 5          2D-PHSENA301                                       pH
# 6          3A-FLORTD101                              Fluorometer
# 7          3A-FLORTD104                              Fluorometer
# 8          3A-FLORTD301                              Fluorometer
# 9          3C-PARADA101   Photosynthetically Available Radiation
# 10         3C-PARADA102  Photosynthetically Available Radiation
# 11         3C-PARADA301   Photosynthetically Available Radiation
# 12         4A-CTDPFA103                                    CTD-O
# 13         4A-CTDPFA109                                    CTD-O
# 14         4A-CTDPFA303                                    CTD-O
# 15         4A-NUTNRA101                                  Nitrate
# 16         4A-NUTNRA102                                  Nitrate
# 17         4A-NUTNRA301                                  Nitrate
# 18         4B-PHSENA102                                       pH
# 19         4B-PHSENA106                                       pH
# 20         4B-PHSENA302                                       pH
# 21         4D-PCO2WA105                                     pCO2
# 22         4F-PCO2WA101                                     pCO2
# 23         4F-PCO2WA102                                     pCO2
# 24         4F-PCO2WA301                                     pCO2
# 25         09-PCO2WB104                                     pCO2
# 26         09-PCO2WB103                                     pCO2
# 27         10-PHSEND107                                       pH
# 28         10-PHSEND103                                       pH
# 29         4C-FLORDD303                              Fluorometer
# 30         4C-FLORDD103                              Fluorometer
# 31         12-CTDPFB301                                    CTD-O
# 32         10-CTDPFB304                                    CTD-O
# 33         12-CTDPFB101                                    CTD-O
# 34         06-CTDBPO108                                    CTD-O
# 35         06-CTDBPN106                                    CTD-O
#
#                                           formal_name  \
# 0                      Conductivity-Temperature-Depth
# 1                      Conductivity-Temperature-Depth
# 2                      Conductivity-Temperature-Depth
# 3                                           pH Sensor
# 4                                           pH Sensor
# 5                                           pH Sensor
# 6                                  Fluorometer (CDOM)
# 7                                  Fluorometer (CDOM)
# 8                                  Fluorometer (CDOM)
# 9   Photosynthetically Available Radiation (PAR) S...
# 10  Photosynthetically Available Radiation (PAR) S...
# 11  Photosynthetically Available Radiation (PAR) S...
# 12                     Conductivity-Temperature-Depth
# 13                     Conductivity-Temperature-Depth
# 14                     Conductivity-Temperature-Depth
# 15                                     Nitrate Sensor
# 16                                     Nitrate Sensor
# 17                                     Nitrate Sensor
# 18                                          pH Sensor
# 19                                          pH Sensor
# 20                                          pH Sensor
# 21                              Carbon Dioxide Sensor
# 22                              Carbon Dioxide Sensor
# 23                              Carbon Dioxide Sensor
# 24                              Carbon Dioxide Sensor
# 25                              Carbon Dioxide Sensor
# 26                              Carbon Dioxide Sensor
# 27                                          pH Sensor
# 28                                          pH Sensor
# 29                                 Fluorometer (CDOM)
# 30                                 Fluorometer (CDOM)
# 31                     Conductivity-Temperature-Depth
# 32                     Conductivity-Temperature-Depth
# 33                     Conductivity-Temperature-Depth
# 34                     Conductivity-Temperature-Depth
# 35                     Conductivity-Temperature-Depth
#
#                                        instrument_url
# 0    /instruments/ctd-conductivity-temperature-depth/
# 1    /instruments/ctd-conductivity-temperature-depth/
# 2    /instruments/ctd-conductivity-temperature-depth/
# 3                                    /instruments/ph/
# 4                                    /instruments/ph/
# 5                                    /instruments/ph/
# 6                           /instruments/fluorometer/
# 7                           /instruments/fluorometer/
# 8                           /instruments/fluorometer/
# 9   /instruments/photosynthetically-active-radiation/
# 10  /instruments/photosynthetically-active-radiation/
# 11  /instruments/photosynthetically-active-radiation/
# 12   /instruments/ctd-conductivity-temperature-depth/
# 13   /instruments/ctd-conductivity-temperature-depth/
# 14   /instruments/ctd-conductivity-temperature-depth/
# 15                       /instruments/nitrate-sensor/
# 16                       /instruments/nitrate-sensor/
# 17                       /instruments/nitrate-sensor/
# 18                                   /instruments/ph/
# 19                                   /instruments/ph/
# 20                                   /instruments/ph/
# 21                       /instruments/carbon-dioxide/
# 22                       /instruments/carbon-dioxide/
# 23                       /instruments/carbon-dioxide/
# 24                       /instruments/carbon-dioxide/
# 25                       /instruments/carbon-dioxide/
# 26                       /instruments/carbon-dioxide/
# 27                                   /instruments/ph/
# 28                                   /instruments/ph/
# 29                          /instruments/fluorometer/
# 30                          /instruments/fluorometer/
# 31   /instruments/ctd-conductivity-temperature-depth/
# 32   /instruments/ctd-conductivity-temperature-depth/
# 33   /instruments/ctd-conductivity-temperature-depth/
# 34   /instruments/ctd-conductivity-temperature-depth/
# 35   /instruments/ctd-conductivity-temperature-depth/

# %% [markdown]
# The search allows us to search all of OOI system for what we want. If `cloud_source` flag is on however, you will only be able to retrieve actual data within CAVA system not OOI.

# %%
ooi.search(region='cabled', site='oregon slope base shallow profiler', instrument='CTD')
# Out:
# <Data Source: OOI (2 Instrument Streams)>

# %% [markdown]
# The `instruments` attribute is a listing of the data that will be fetched.

# %%
ooi.instruments
# Out:
#                                  array_name  \
# 0  Cabled Continental Margin (Cabled Array)
# 1  Cabled Continental Margin (Cabled Array)
#
#                                     site_name       infrastructure_name  \
# 0  Oregon Slope Base Shallow Profiler Mooring     200m Platform (PC01A)
# 1  Oregon Slope Base Shallow Profiler Mooring  Shallow Profiler (SF01A)
#
#   instrument_name stream_method            stream_rd
# 0             CTD      streamed  ctdpf_optode_sample
# 1             CTD      streamed   ctdpf_sbe43_sample

# %%
# This example is designed to showcase basic data download
# over the time period of the 2017 solar eclipse

stdt = '2017-08-20'
enddt = '2017-08-24'

req_asset = ooi.request_data(
    begin_date=stdt,
    end_date=enddt
)

# %% [markdown]
# The `raw` function shows the list of zarr files fetched.

# %%
req_asset.raw()
# Out:
# [                                                   uri       time
#  810  io2data/data/RS01SBPS-SF01A-2A-CTDPFA102-strea... 2017-08-20
#  811  io2data/data/RS01SBPS-SF01A-2A-CTDPFA102-strea... 2017-08-21
#  812  io2data/data/RS01SBPS-SF01A-2A-CTDPFA102-strea... 2017-08-22
#  813  io2data/data/RS01SBPS-SF01A-2A-CTDPFA102-strea... 2017-08-23
#  814  io2data/data/RS01SBPS-SF01A-2A-CTDPFA102-strea... 2017-08-24,
#                                                     uri       time
#  995  io2data/data/RS01SBPS-PC01A-4A-CTDPFA103-strea... 2017-08-20
#  996  io2data/data/RS01SBPS-PC01A-4A-CTDPFA103-strea... 2017-08-21
#  997  io2data/data/RS01SBPS-PC01A-4A-CTDPFA103-strea... 2017-08-22
#  998  io2data/data/RS01SBPS-PC01A-4A-CTDPFA103-strea... 2017-08-23
#  999  io2data/data/RS01SBPS-PC01A-4A-CTDPFA103-strea... 2017-08-24]

# %%
# to get the actual data in list of xarray datasets
ds_list = ooi.to_xarray()

# %%
ds_list
# Out:
# [<xarray.Dataset>
#  Dimensions:                                 (time: 345592)
#  Coordinates:
#    * time                                    (time) datetime64[ns] 2017-08-20T...
#      lat                                     (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      lon                                     (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      seawater_pressure                       (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#  Data variables: (12/29)
#      conductivity                            (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      corrected_dissolved_oxygen              (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      corrected_dissolved_oxygen_qc_executed  (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      corrected_dissolved_oxygen_qc_results   (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      density                                 (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      density_qc_executed                     (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      ...                                      ...
#      seawater_pressure_qc_executed           (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      seawater_pressure_qc_results            (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      seawater_temperature                    (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      seawater_temperature_qc_executed        (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      seawater_temperature_qc_results         (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>
#      temperature                             (time) float64 dask.array<chunksize=(96398,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:                            (time: 345598)
#  Coordinates:
#    * time                               (time) datetime64[ns] 2017-08-20T00:00...
#      lat                                (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      lon                                (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      seawater_pressure                  (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#  Data variables: (12/34)
#      conductivity                       (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      ctd_tc_oxygen                      (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      ctd_tc_oxygen_qc_executed          (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      ctd_tc_oxygen_qc_results           (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      density                            (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      density_qc_executed                (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      ...                                 ...
#      seawater_pressure_qc_executed      (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      seawater_pressure_qc_results       (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      seawater_temperature               (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      seawater_temperature_qc_executed   (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      seawater_temperature_qc_results    (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>
#      temperature                        (time) float64 dask.array<chunksize=(96399,), meta=np.ndarray>]

# %%
import xarray as xr
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from yodapy.utils.parser import seconds_to_date

# %%
# Plot a simple timeseries of temperature, and PSU vs. pressure
ds = ds_list[0]

# %%
# pull out values from the xarray structure
pressure = ds['seawater_pressure'].data
temperature = ds['seawater_temperature'].data
psu = ds['practical_salinity'].data
ds_time = ds['time'].data

# quick and dirty timeseries plot of temperature for sanity check
plt.plot(ds_time,temperature)
plt.show()

# %%
# Now, more complete colored scatter plot, with data plotted
# on a depth vs. time axis.

fig,(ax1,ax2) = plt.subplots(nrows=2,ncols=1)
fig.set_size_inches(16,9)

# plot temp and salinity curtain plots
ax1.invert_yaxis()
ax1.grid()
ax1.set_xlim(ds_time[0],ds_time[-1])
sc1 = ax1.scatter(ds_time,pressure,c=temperature)
ax1.set_xlabel('Date')
ax1.set_ylabel('Pressure (dbar)')
ax1.set_title('Temperature (degC)')
cb = fig.colorbar(sc1,ax=ax1)

ax2.invert_yaxis()
ax2.grid()
ax2.set_xlim(ds_time[0],ds_time[-1])
ax2.set_xlabel('Date')
ax2.set_ylabel('Pressure (dbar)')
ax2.set_title('Salinity (psu)')
sc2 = ax2.scatter(ds_time,pressure,c=psu)
cb2 = fig.colorbar(sc2,ax=ax2)
plt.show()

# %%
# Now, more complete colored scatter plot, with data plotted
# on a temperature vs. salinty axis, color coded for depth

fig2,(ax3) = plt.subplots(nrows=1,ncols=1)
fig2.set_size_inches(16,10)

sc3 = ax3.scatter(psu,temperature,c=(-1.0*pressure))
ax3.set_title('Temperature vs. PSU, color coded for Depth')
ax3.set_xlabel('PSU')
ax3.set_ylabel('Temperature (degC)')
cb = fig.colorbar(sc3,ax=ax3)
cb.set_label('Depth (negative decibars)')
plt.show()

# %%
fig3,ax4 = plt.subplots(nrows=1,ncols=1)
fig3.set_size_inches(6,4)

hb = ax4.hexbin(psu,temperature,
                gridsize=50,
                bins='log',
                cmap=plt.cm.GnBu)
ax4.set_title('Hexagon Binning')
ax4.set_xlabel('PSU')
ax4.set_ylabel('Temperature (degC)')
cb = fig3.colorbar(hb, ax=ax4)
cb.set_label('log10(N)')
plt.show()

# %%
# Now, more complete colored scatter plot, with data plotted
# on a temperature vs. salinty axis, color coded for time (in seconds
# since )

fig2,(ax3) = plt.subplots(nrows=1,ncols=1)
fig2.set_size_inches(16,10)

sc3 = ax3.scatter(psu,temperature,c=(ds.time.data))
ax3.set_title('Temperature vs. PSU')
ax3.set_xlabel('PSU')
ax3.set_ylabel('Temperature (degC)')
cb = fig.colorbar(sc3,ax=ax3)
cb.set_label('raw time')
plt.show()
